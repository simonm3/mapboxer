# %%
from ipstartup import *
import geopandas as gpd
df = pd.read_csv(r"C:\Users\simon\Downloads\connect_data_with_geocodes.csv")
df = gpd.GeoDataFrame(df)
# Out:
# [cellevents:43:INFO]:starting (time=Aug-15 19:46 MainProcess)
# time: 191 ms

# %%
df
# Out:
# [cellevents:43:INFO]:starting (time=Aug-15 19:46 MainProcess)
#            vanid   latitude  longitude localauthorityname  \
# 0       49170833  50.625534  -2.514221             Dorset
# 1       49271013  50.745282  -2.342942             Dorset
# 2        4908872  50.809800  -2.730556             Dorset
# 3        4908885  50.809383  -2.738833             Dorset
# 4        4908932  50.810751  -2.738150             Dorset
# ...          ...        ...        ...                ...
# 81455  105765456        NaN        NaN             Dorset
# 81456  105765464        NaN        NaN             Dorset
# 81457  105765465        NaN        NaN             Dorset
# 81458  105765698        NaN        NaN             Dorset
# 81459  105765699        NaN        NaN             Dorset
#
#                              wardname pollingdistrictcode  \
# 0                          Chickerell                CHC4
# 1      Puddletown & Lower Winterborne                PUD6
# 2                          Beaminster                BEM1
# 3                          Beaminster                BEM1
# 4                          Beaminster                BEM1
# ...                               ...                 ...
# 81455                        Bridport               BRD10
# 81456                        Bridport               BRD11
# 81457                        Bridport               BRD11
# 81458            Dorchester Poundbury                DRP1
# 81459            Dorchester Poundbury                DRP1
#
#            pollingdistrictname postalcode    likelypartyname recent_mpid  tps  \
# 0      CHC4 - Chickerell North    DT3 4DL            No Data         NaN  NaN
# 1            PUD6 - Puddletown    DT2 8XF            No Data         NaN  NaN
# 2            BEM1 - Beaminster    DT8 3EY            No Data         NaN  Not
# 3            BEM1 - Beaminster    DT8 3EF            No Data         NaN  Lnd
# 4            BEM1 - Beaminster    DT8 3EH  Weak Conservative         NaN  Lnd
# ...                        ...        ...                ...         ...  ...
# 81455   BRD10 - Bridport South    DT6 3XB            No Data         NaN  NaN
# 81456   BRD11 - Bridport South    DT6 4HE            No Data         NaN  NaN
# 81457   BRD11 - Bridport South    DT6 4HE            No Data         NaN  NaN
# 81458         DRP1 - Poundbury    DT1 3FN            No Data         NaN  NaN
# 81459         DRP1 - Poundbury    DT1 3FN            No Data         NaN  NaN
#
#       tory_facing life_stage register_history volunteer_prospects
# 0             Sw+         EE               NR                 NaN
# 1             Sw+         EE              VNR                 NaN
# 2             Unk        60+               VN                 NaN
# 3             Unk         EE               VN                 NaN
# 4             Sta         EE               VN                 NaN
# ...           ...        ...              ...                 ...
# 81455         Unk         EE              N20                 NaN
# 81456         Unk         EE              N20                 NaN
# 81457         Unk         EE              N20                 NaN
# 81458         Unk         EE              N20                 NaN
# 81459         Unk         EE              N20                 NaN
#
# [81460 rows x 15 columns]
# time: 55 ms
